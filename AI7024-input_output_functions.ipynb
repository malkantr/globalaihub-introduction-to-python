# %%
print("Hi, this is Python")
# Out:
# Hi, this is Python

# %%
name = "Deniz"
print(name)
# Out:
# Deniz

# %%
name = "Selin"
print('Hello', name)
# Out:
# Hello Selin

# %%
print(15)
# Out:
# 15

# %%
name = input('Name:')
print('Greetings', name)
# Out:
# Name:global ai
# Greetings global ai

# %%
number = input("Number: ")
print(int(number) + 10)
# Out:
# Number: 5
# 15

# %%
number = int(input("Number: "))
print(number + 10)
# Out:
# Number: 5
# 15
