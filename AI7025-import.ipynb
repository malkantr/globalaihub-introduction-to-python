# %%
import math

# %%
floor_number = (math.floor(3.45))
print(floor_number, type(floor_number))
print(type(3.45))
# Out:
# 3 <class 'int'>
# <class 'float'>

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2023-03-28 10:03:00.339866

# %%
import random

print(random.randint(1,6))
# Out:
# 1
